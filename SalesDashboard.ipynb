# %% [markdown]
# <a href="https://colab.research.google.com/github/kavyatalam08/assignment3/blob/main/SalesDashboard.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
# ---------------------------------------------------------
#                 EMPLOYEE PAYROLL DASHBOARD
# ---------------------------------------------------------
st.title("💼 Employee Payroll Dashboard")
# ---------------------------------------------------------
# Employee : Rahul Sharma
# Department : Analytics
# Designation : Data Analyst
# ---------------------------------------------------------
st.header("Employee Information")
st.write("**Employee :** Rahul Sharma")
st.write("**Department :** Analytics")
st.write("**Designation :** Data Analyst")
# ---------------------------------------------------------
# Gross Salary     Net Salary     Deductions     Paid Days
# ₹105,000         ₹95,000         ₹10,000          31
# ---------------------------------------------------------
col1, col2, col3, col4 = st.columns(4)
col1.metric("Gross Salary", "₹105,000")
col2.metric("Net Salary", "₹95,000")
col3.metric("Deductions", "₹10,000")
col4.metric("Paid Days", "31")
st.divider()
# ---------------------------------------------------------
# Salary Components (Bar Chart)
# ---------------------------------------------------------
salary = pd.DataFrame({
    "Component": ["Basic Salary", "HRA", "Medical", "Special Allowance", "Bonus"],
    "Amount": [60000, 24000, 4000, 9000, 5000]
})
st.subheader("Salary Components (Bar Chart)")
fig, ax = plt.subplots()
ax.bar(salary["Component"], salary["Amount"])
plt.xticks(rotation=20)
st.pyplot(fig)
# ---------------------------------------------------------
# Earnings Distribution (Pie Chart)
# ---------------------------------------------------------
st.subheader("Earnings Distribution (Pie Chart)")
fig, ax = plt.subplots()
ax.pie(
    salary["Amount"],
    labels=salary["Component"],
    autopct="%1.1f%%",
    startangle=90
)
ax.axis("equal")
st.pyplot(fig)
# ---------------------------------------------------------
# Gross vs Deduction vs Net (Bar Chart)
# ---------------------------------------------------------
st.subheader("Gross vs Deduction vs Net (Bar Chart)")
fig, ax = plt.subplots()
ax.bar(
    ["Gross", "Deduction", "Net"],
    [105000, 10000, 95000]
)
st.pyplot(fig)
# ---------------------------------------------------------
# Employee Details
# Bank Name
# Account Number
# PAN
# Joining Date
# ---------------------------------------------------------
st.subheader("Employee Details")
details = pd.DataFrame({
    "Field": [
        "Bank Name",
        "Account Number",
        "PAN",
        "Joining Date"
    ],
    "Value": [
        "State Bank of India",
        "123456789012",
        "ABCDE1234F",
        "15-Jan-2023"
    ]
})
st.table(details)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_1167/1902810346.py in <cell line: 0>()
# ----> 1 import streamlit as st
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
#       4 # ---------------------------------------------------------
#       5 #                 EMPLOYEE PAYROLL DASHBOARD
#
# ModuleNotFoundError: No module named 'streamlit'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
c4.metric("Paid Days", "31")
st.markdown("---")
# ---------------------------------------------------
# Salary Components Data
# ---------------------------------------------------
components = [
    "Basic Salary",
    "HRA",
    "Conveyance",
    "Medical",
    "Special Allowance",
    "Bonus"
]
amount = [
    60000,
    20000,
    5000,
    3000,
    12000,
    5000
]
# ---------------------------------------------------
# Salary Components Bar Chart
# ---------------------------------------------------
st.subheader("📊 Salary Components")
fig1, ax1 = plt.subplots(figsize=(10,5))
ax1.bar(components, amount)
ax1.set_title("Salary Components", fontsize=15)
ax1.set_xlabel("Salary Component")
ax1.set_ylabel("Amount (₹)")
plt.xticks(rotation=20)
st.pyplot(fig1)
st.markdown("---")
# ---------------------------------------------------
# Earnings Distribution Pie Chart
# ---------------------------------------------------
st.subheader("🥧 Earnings Distribution")
fig2, ax2 = plt.subplots(figsize=(8,8))
ax2.pie(
    amount,
    labels=components,
    autopct="%1.1f%%",
    startangle=90
)
ax2.set_title("Salary Distribution", fontsize=15)
st.pyplot(fig2)
st.markdown("---")
# ---------------------------------------------------
# Gross vs Deduction vs Net
# ---------------------------------------------------
st.subheader("📈 Gross vs Deduction vs Net")
labels = [
    "Gross Salary",
    "Deduction",
    "Net Salary"
]
values = [
    gross,
    deduction,
    net
]
fig3, ax3 = plt.subplots(figsize=(8,5))
ax3.bar(labels, values)
ax3.set_title("Gross vs Deduction vs Net", fontsize=15)
ax3.set_xlabel("Salary Type")
ax3.set_ylabel("Amount (₹)")
st.pyplot(fig3)
st.markdown("---")
# ---------------------------------------------------
# Employee Details
# ---------------------------------------------------
st.header("🏦 Employee Details")
employee = pd.DataFrame({
    "Field": [
        "Bank Name",
        "Account Number",
        "PAN Number",
        "Joining Date"
    ],
    "Details": [
        "State Bank of India",
        "XXXX XXXX 4587",
        "ABCDE1234F",
        "15-Jan-2024"
    ]
})
st.table(employee)
st.markdown("---")
st.success("✅ Employee Payroll Dashboard Generated Successfully")
# Out:
# 2026-08-06 09:06:48.975 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 09:06:48.976 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 09:06:48.977 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 09:06:48.978 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 09:06:48.980 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 09:06:48.980 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 09:06:48.981 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
import streamlit as st
import pandas as pd



c1, c2, c3, c4 = st.columns(4)

c1.metric("Basic Salary", "₹30,000")
c2.metric("HRA", "₹12,000")
c3.metric("Working Days", "31")
c4.metric("Paid Days", "31")
# Out:
# 2026-08-06 09:06:34.109 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 09:06:34.110 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 09:06:34.111 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 09:06:34.114 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 09:06:34.115 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
# !pip install streamlit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 80.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 90.5 MB/s eta 0:00:00
# ...

# %%
# %%writefile app.py
import streamlit as st
import pandas as pd

st.title("Employee Payroll Dashboard")

c1, c2, c3, c4 = st.columns(4)

c1.metric("Basic Salary", "₹30,000")
c2.metric("HRA", "₹12,000")
c3.metric("Working Days", "31")
c4.metric("Paid Days", "31")
# Out:
# Writing app.py

# %%
# !streamlit run app.py
# Out:
# ...
#
# 2026-08-06 09:09:24.178 Uvicorn server started on :::8501
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://136.114.89.206:8501
#
#   Stopping...
#   Stopping...

# %%
gross = 60000
deduction = 5000
net = gross - deduction

values = [
    gross,
    deduction,
    net
]

# %%
c4.metric("Paid Days", "31")
st.markdown("---")
# ---------------------------------------------------
# Salary Components Data
# ---------------------------------------------------
components = [
    "Basic Salary",
    "HRA",
    "Conveyance",
    "Medical",
    "Special Allowance",
    "Bonus"
]
amount = [
    60000,
    20000,
    5000,
    3000,
    12000,
    5000
]
# ---------------------------------------------------
# Salary Components Bar Chart
# ---------------------------------------------------
st.subheader("📊 Salary Components")
fig1, ax1 = plt.subplots(figsize=(10,5))
ax1.bar(components, amount)
ax1.set_title("Salary Components", fontsize=15)
ax1.set_xlabel("Salary Component")
ax1.set_ylabel("Amount (₹)")
plt.xticks(rotation=20)
st.pyplot(fig1)
st.markdown("---")
# ---------------------------------------------------
# Earnings Distribution Pie Chart
# ---------------------------------------------------
st.subheader("🥧 Earnings Distribution")
fig2, ax2 = plt.subplots(figsize=(8,8))
ax2.pie(
    amount,
    labels=components,
    autopct="%1.1f%%",
    startangle=90
)
ax2.set_title("Salary Distribution", fontsize=15)
st.pyplot(fig2)
st.markdown("---")
# ---------------------------------------------------
# Gross vs Deduction vs Net
# ---------------------------------------------------
st.subheader("📈 Gross vs Deduction vs Net")
labels = [
    "Gross Salary",
    "Deduction",
    "Net Salary"
]
values = [
    gross,
    deduction,
    net
]
fig3, ax3 = plt.subplots(figsize=(8,5))
ax3.bar(labels, values)
ax3.set_title("Gross vs Deduction vs Net", fontsize=15)
ax3.set_xlabel("Salary Type")
ax3.set_ylabel("Amount (₹)")
st.pyplot(fig3)
st.markdown("---")
# ---------------------------------------------------
# Employee Details
# ---------------------------------------------------
st.header("🏦 Employee Details")
employee = pd.DataFrame({
    "Field": [
        "Bank Name",
        "Account Number",
        "PAN Number",
        "Joining Date"
    ],
    "Details": [
        "State Bank of India",
        "XXXX XXXX 4587",
        "ABCDE1234F",
        "15-Jan-2024"
    ]
})
st.table(employee)
st.markdown("---")
st.success("✅ Employee Payroll Dashboard Generated Successfully")
# Out:
# 2026-08-06 09:26:49.536 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 09:26:49.537 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 09:26:49.538 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 09:26:49.539 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 09:26:49.540 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 09:26:49.541 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 09:26:49.543 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
gross = 60000
deduction = 5000
net = gross - deduction

values = [
    gross,
    deduction,
    net
]

# %%
c4.metric("Paid Days", "31")
st.markdown("---")
# ---------------------------------------------------
# Salary Components Data
# ---------------------------------------------------
components = [
    "Basic Salary",
    "HRA",
    "Conveyance",
    "Medical",
    "Special Allowance",
    "Bonus"
]
amount = [
    60000,
    20000,
    5000,
    3000,
    12000,
    5000
]
# ---------------------------------------------------
# Salary Components Bar Chart
# ---------------------------------------------------
st.subheader("📊 Salary Components")
fig1, ax1 = plt.subplots(figsize=(10,5))
ax1.bar(components, amount)
ax1.set_title("Salary Components", fontsize=15)
ax1.set_xlabel("Salary Component")
ax1.set_ylabel("Amount (₹)")
plt.xticks(rotation=20)
st.pyplot(fig1)
st.markdown("---")
# ---------------------------------------------------
# Earnings Distribution Pie Chart
# ---------------------------------------------------
st.subheader("🥧 Earnings Distribution")
fig2, ax2 = plt.subplots(figsize=(8,8))
ax2.pie(
    amount,
    labels=components,
    autopct="%1.1f%%",
    startangle=90
)
ax2.set_title("Salary Distribution", fontsize=15)
st.pyplot(fig2)
st.markdown("---")
# ---------------------------------------------------
# Gross vs Deduction vs Net
# ---------------------------------------------------
st.subheader("📈 Gross vs Deduction vs Net")
labels = [
    "Gross Salary",
    "Deduction",
    "Net Salary"
]
values = [
    gross,
    deduction,
    net
]
fig3, ax3 = plt.subplots(figsize=(8,5))
ax3.bar(labels, values)
ax3.set_title("Gross vs Deduction vs Net", fontsize=15)
ax3.set_xlabel("Salary Type")
ax3.set_ylabel("Amount (₹)")
st.pyplot(fig3)
st.markdown("---")
# ---------------------------------------------------
# Employee Details
# ---------------------------------------------------
st.header("🏦 Employee Details")
employee = pd.DataFrame({
    "Field": [
        "Bank Name",
        "Account Number",
        "PAN Number",
        "Joining Date"
    ],
    "Details": [
        "State Bank of India",
        "XXXX XXXX 4587",
        "ABCDE1234F",
        "15-Jan-2024"
    ]
})
st.table(employee)
st.markdown("---")
st.success("✅ Employee Payroll Dashboard Generated Successfully")
# Out:
# 2026-08-06 09:27:28.056 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 09:27:28.057 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 09:27:28.059 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 09:27:28.060 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 09:27:28.061 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 09:27:28.061 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 09:27:28.063 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
# ---------------------------------------------------------
#                 EMPLOYEE PAYROLL DASHBOARD
# ---------------------------------------------------------
st.title("💼 Employee Payroll Dashboard")
# ---------------------------------------------------------
# Employee : Rahul Sharma
# Department : Analytics
# Designation : Data Analyst
# ---------------------------------------------------------
st.header("Employee Information")
st.write("**Employee :** Rahul Sharma")
st.write("**Department :** Analytics")
st.write("**Designation :** Data Analyst")
# ---------------------------------------------------------
# Gross Salary     Net Salary     Deductions     Paid Days
# ₹105,000         ₹95,000         ₹10,000          31
# ---------------------------------------------------------
col1, col2, col3, col4 = st.columns(4)
col1.metric("Gross Salary", "₹105,000")
col2.metric("Net Salary", "₹95,000")
col3.metric("Deductions", "₹10,000")
col4.metric("Paid Days", "31")
st.divider()
# ---------------------------------------------------------
# Salary Components (Bar Chart)
# ---------------------------------------------------------
salary = pd.DataFrame({
    "Component": ["Basic Salary", "HRA", "Medical", "Special Allowance", "Bonus"],
    "Amount": [60000, 24000, 4000, 9000, 5000]
})
st.subheader("Salary Components (Bar Chart)")
fig, ax = plt.subplots()
ax.bar(salary["Component"], salary["Amount"])
plt.xticks(rotation=20)
st.pyplot(fig)
# ---------------------------------------------------------
# Earnings Distribution (Pie Chart)
# ---------------------------------------------------------
st.subheader("Earnings Distribution (Pie Chart)")
fig, ax = plt.subplots()
ax.pie(
    salary["Amount"],
    labels=salary["Component"],
    autopct="%1.1f%%",
    startangle=90
)
ax.axis("equal")
st.pyplot(fig)
# ---------------------------------------------------------
# Gross vs Deduction vs Net (Bar Chart)
# ---------------------------------------------------------
st.subheader("Gross vs Deduction vs Net (Bar Chart)")
fig, ax = plt.subplots()
ax.bar(
    ["Gross", "Deduction", "Net"],
    [105000, 10000, 95000]
)
st.pyplot(fig)
# ---------------------------------------------------------
# Employee Details
# Bank Name
# Account Number
# PAN
# Joining Date
# ---------------------------------------------------------
st.subheader("Employee Details")
details = pd.DataFrame({
    "Field": [
        "Bank Name",
        "Account Number",
        "PAN",
        "Joining Date"
    ],
    "Value": [
        "State Bank of India",
        "123456789012",
        "ABCDE1234F",
        "15-Jan-2023"
    ]
})
st.table(details)
# Out:
# 2026-08-06 09:28:45.842 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 09:28:45.844 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 09:28:45.845 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 09:28:45.847 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 09:28:45.848 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 09:28:45.849 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 09:28:45.851 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
# ---------------------------------------------------------
#                 EMPLOYEE PAYROLL DASHBOARD
# ---------------------------------------------------------
st.title("💼 Employee Payroll Dashboard")
# ---------------------------------------------------------
# Employee : Rahul Sharma
# Department : Analytics
# Designation : Data Analyst
# ---------------------------------------------------------
st.header("Employee Information")
st.write("**Employee :** Rahul Sharma")
st.write("**Department :** Analytics")
st.write("**Designation :** Data Analyst")
# ---------------------------------------------------------
# Gross Salary     Net Salary     Deductions     Paid Days
# ₹105,000         ₹95,000         ₹10,000          31
# ---------------------------------------------------------
col1, col2, col3, col4 = st.columns(4)
col1.metric("Gross Salary", "₹105,000")
col2.metric("Net Salary", "₹95,000")
col3.metric("Deductions", "₹10,000")
col4.metric("Paid Days", "31")
st.divider()
# ---------------------------------------------------------
# Salary Components (Bar Chart)
# ---------------------------------------------------------
salary = pd.DataFrame({
    "Component": ["Basic Salary", "HRA", "Medical", "Special Allowance", "Bonus"],
    "Amount": [60000, 24000, 4000, 9000, 5000]
})
st.subheader("Salary Components (Bar Chart)")
fig, ax = plt.subplots()
ax.bar(salary["Component"], salary["Amount"])
plt.xticks(rotation=20)
st.pyplot(fig)
# ---------------------------------------------------------
# Earnings Distribution (Pie Chart)
# ---------------------------------------------------------
st.subheader("Earnings Distribution (Pie Chart)")
fig, ax = plt.subplots()
ax.pie(
    salary["Amount"],
    labels=salary["Component"],
    autopct="%1.1f%%",
    startangle=90
)
ax.axis("equal")
st.pyplot(fig)
# ---------------------------------------------------------
# Gross vs Deduction vs Net (Bar Chart)
# ---------------------------------------------------------
st.subheader("Gross vs Deduction vs Net (Bar Chart)")
fig, ax = plt.subplots()
ax.bar(
    ["Gross", "Deduction", "Net"],
    [105000, 10000, 95000]
)
st.pyplot(fig)
# ---------------------------------------------------------
# Employee Details
# Bank Name
# Account Number
# PAN
# Joining Date
# ---------------------------------------------------------
st.subheader("Employee Details")
details = pd.DataFrame({
    "Field": [
        "Bank Name",
        "Account Number",
        "PAN",
        "Joining Date"
    ],
    "Value": [
        "State Bank of India",
        "123456789012",
        "ABCDE1234F",
        "15-Jan-2023"
    ]
})
st.table(details)

# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt

# -------------------------------
# Dashboard Title
# -------------------------------
st.title("📊 ABC Store Sales Dashboard")

# -------------------------------
# Store Information
# -------------------------------
st.header("Store Information")

st.write("**Store Name:** ABC Store")
st.write("**Location:** Hyderabad")
st.write("**Manager:** Rahul Sharma")

# -------------------------------
# KPI Cards
# -------------------------------
col1, col2, col3, col4 = st.columns(4)

col1.metric("Total Sales", "$250,000")
col2.metric("Profit", "$75,000")
col3.metric("Orders", "1,250")
col4.metric("Customers", "980")

st.divider()

# -------------------------------
# Monthly Sales
# -------------------------------
monthly_sales = pd.DataFrame({
    "Month": [
        "Jan",
        "Feb",
        "Mar",
        "Apr",
        "May",
        "Jun"
    ],
    "Sales": [
        30000,
        35000,
        42000,
        38000,
        50000,
        55000
    ]
})

st.subheader("Monthly Sales (Line Chart)")

fig, ax = plt.subplots(figsize=(7,4))

ax.plot(
    monthly_sales["Month"],
    monthly_sales["Sales"],
    marker="o"
)

ax.set_xlabel("Month")
ax.set_ylabel("Sales ($)")

st.pyplot(fig)

st.divider()

# -------------------------------
# Product Sales
# -------------------------------
product_sales = pd.DataFrame({
    "Product": [
        "Laptop",
        "Mobile",
        "Headphones",
        "Keyboard",
        "Mouse",
        "Monitor"
    ],
    "Sales": [
        60000,
        50000,
        30000,
        20000,
        15000,
        25000
    ]
})

st.subheader("Product Sales (Bar Chart)")

fig, ax = plt.subplots(figsize=(7,4))

ax.bar(
    product_sales["Product"],
    product_sales["Sales"]
)

ax.set_xlabel("Products")
ax.set_ylabel("Sales ($)")

st.pyplot(fig)

st.divider()

# -------------------------------
# Category Sales
# -------------------------------
category_sales = pd.DataFrame({
    "Category": [
        "Electronics",
        "Accessories",
        "Home Appliances",
        "Furniture"
    ],
    "Sales": [
        120000,
        50000,
        45000,
        35000
    ]
})

st.subheader("Category Sales (Pie Chart)")

fig, ax = plt.subplots(figsize=(6,6))

ax.pie(
    category_sales["Sales"],
    labels=category_sales["Category"],
    autopct="%1.1f%%",
    startangle=90
)

st.pyplot(fig)

st.divider()

# -------------------------------
# Top Selling Products Table
# -------------------------------
st.subheader("Top Selling Products")

top_products = pd.DataFrame({
    "Product": [
        "Laptop",
        "Mobile",
        "Headphones",
        "Monitor",
        "Keyboard"
    ],
    "Units Sold": [
        320,
        280,
        240,
        180,
        160
    ],
    "Revenue ($)": [
        60000,
        50000,
        30000,
        25000,
        20000
    ]
})

st.table(top_products)
# Out:
# 2026-08-06 09:44:19.030 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 09:44:19.032 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 09:44:19.033 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 09:44:19.034 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 09:44:19.036 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 09:44:19.037 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-06 09:44:19.038 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt

# -------------------------------
# Dashboard Title
# -------------------------------
st.title("📊 ABC Store Sales Dashboard")

# -------------------------------
# Store Information
# -------------------------------
st.header("Store Information")

st.write("**Store Name:** ABC Store")
st.write("**Location:** Hyderabad")
st.write("**Manager:** Rahul Sharma")

# -------------------------------
# KPI Cards
# -------------------------------
col1, col2, col3, col4 = st.columns(4)

col1.metric("Total Sales", "$250,000")
col2.metric("Profit", "$75,000")
col3.metric("Orders", "1,250")
col4.metric("Customers", "980")

st.divider()

# -------------------------------
# Monthly Sales
# -------------------------------
monthly_sales = pd.DataFrame({
    "Month": [
        "Jan",
        "Feb",
        "Mar",
        "Apr",
        "May",
        "Jun"
    ],
    "Sales": [
        30000,
        35000,
        42000,
        38000,
        50000,
        55000
    ]
})

st.subheader("Monthly Sales (Line Chart)")

fig, ax = plt.subplots(figsize=(7,4))

ax.plot(
    monthly_sales["Month"],
    monthly_sales["Sales"],
    marker="o"
)

ax.set_xlabel("Month")
ax.set_ylabel("Sales ($)")

st.pyplot(fig)

st.divider()

# -------------------------------
# Product Sales
# -------------------------------
product_sales = pd.DataFrame({
    "Product": [
        "Laptop",
        "Mobile",
        "Headphones",
        "Keyboard",
        "Mouse",
        "Monitor"
    ],
    "Sales": [
        60000,
        50000,
        30000,
        20000,
        15000,
        25000
    ]
})

st.subheader("Product Sales (Bar Chart)")

fig, ax = plt.subplots(figsize=(7,4))

ax.bar(
    product_sales["Product"],
    product_sales["Sales"]
)

ax.set_xlabel("Products")
ax.set_ylabel("Sales ($)")

st.pyplot(fig)

st.divider()

# -------------------------------
# Category Sales
# -------------------------------
category_sales = pd.DataFrame({
    "Category": [
        "Electronics",
        "Accessories",
        "Home Appliances",
        "Furniture"
    ],
    "Sales": [
        120000,
        50000,
        45000,
        35000
    ]
})

st.subheader("Category Sales (Pie Chart)")

fig, ax = plt.subplots(figsize=(6,6))

ax.pie(
    category_sales["Sales"],
    labels=category_sales["Category"],
    autopct="%1.1f%%",
    startangle=90
)

st.pyplot(fig)

st.divider()

# -------------------------------
# Top Selling Products Table
# -------------------------------
st.subheader("Top Selling Products")

top_products = pd.DataFrame({
    "Product": [
        "Laptop",
        "Mobile",
        "Headphones",
        "Monitor",
        "Keyboard"
    ],
    "Units Sold": [
        320,
        280,
        240,
        180,
        160
    ],
    "Revenue ($)": [
        60000,
        50000,
        30000,
        25000,
        20000
    ]
})

st.table(top_products)
